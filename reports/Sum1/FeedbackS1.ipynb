# %%
Estimado equipo (Wilson, Luis, Mauricio y Eduardo):

El avance de Fase 1 es de un nivel técnico muy alto y se nota un trabajo serio y bien organizado. Antes de las mejoras, vale la pena que reconozcan 
lo que hicieron especialmente bien, porque son prácticas que conviene sostener: el EDA real sobre el dataset (dimensiones, tipos, nulos, describe 
y visualizaciones) ejecutado sin errores; una reproducibilidad verificada de forma automática mediante GitHub Actions, que ejecuta el notebook en un
entorno limpio en cada cambio —el mecanismo más robusto que vimos—; un repositorio muy completo y profesional (estructura modular, CI/CD, estrategia 
de ramas y Pull Requests); y la mejor vinculación con el mapa conceptual, incluyendo la figura del mapa y la distinción explícita entre lo materializado
en F1 y lo proyectado. Ese estándar es el que deben mantener en F2, F3 y F4.


    
    
    Para que las próximas entregas suban aún más, enfóquense en estos hábitos:

1. Hagan trazable la contribución individual en Git. Tienen un flujo de ramas, PRs y CI excelente, pero los commits aparecen bajo la cuenta
    de la organización (GRUPO3MCDI500)y las ramas se organizan por componente, no por persona. 
    La rúbrica valora que se pueda identificar el aporte de cada integrante. 
    Para F2: que cada uno commitee desde su propia cuenta de GitHub (con user.name/user.email configurados) y, si quieren, 
    documenten en el README quién trabajó qué. Es el punto que más fácilmente eleva la nota.

2. Cierren el ciclo de APA 7. La bibliografía cubre bien el material docente y la documentación oficial, pero faltan dos cosas: 
    al menos una fuente académica complementaria reciente (un paper o libro científico, no solo documentación de librerías) y, sobre todo, 
    las citas en el cuerpo del texto. Regla práctica: toda fuente del listado debe aparecer citada al menos una vez en el informe, y toda 
    afirmación de respaldo debe llevar su cita.

3. Afinen la reproducibilidad documentada. La verificación por CI es excelente; complétenla documentando explícitamente la creación y activación
    del entorno virtual (.venv) y fijando versiones exactas (==) en requirements.txt en lugar de rangos >=, para garantizar entornos idénticos
    entre equipos.

4. Cuiden la coherencia entre documentos. Detectamos dos inconsistencias menores: el nombre del curso en la portada 
    ("Herramientas de software científico" en vez de "Programación para la Ciencia de Datos") 
    y el nombre de un integrante, que aparece distinto en el notebook ("Eduardo Sanhueza") y en el informe 
    ("Eduardo Garrido"). Unifíquenlos para que portada, notebook, informe y repositorio sean consistentes.

5. Proyecten la modularidad hacia src/. Ya tienen la carpeta creada; en F2 lleven la lógica de carga y exploración a módulos en src/ e impórtenlos
    desde el notebook. Eso refuerza la reutilización y la mantenibilidad, y aprovecha mejor la estructura que ya montaron.

    En síntesis: tienen una base técnica, de reproducibilidad y de organización excelente —de las más sólidas del curso—. 
    El salto de calidad vendrá sobre todo de visibilizar el aporte individual de cada integrante en Git y de cerrar los detalles formales
    (citas en texto, fuente académica y coherencia de nombres). Si incorporan estos hábitos, el proyecto no solo mejorará en evaluación, 
    sino que será un ejemplo de buenas prácticas para las fases siguientes.

 

Saludos.
